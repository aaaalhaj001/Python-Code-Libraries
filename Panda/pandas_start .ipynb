# %%
import pandas as pd

#poke=pd.read_csv('pokemon_data.csv')
#print(poke)

pok=pd.read_csv('pokemon_data.csv')
print(poke)
#pok=pd.read_excel('pokemon_data.xlsx')
#print(pok.head(3))

#po=pd.read_csv('pokemon_data.txt',delimiter'\t')
#print(po)

# %%
##read Headers
#poke.columns

##read each Headers
#print (poke[['Name','Type 1' , 'Type 2']])
##read each row
#print (poke.iloc[1:4])
#for index,row in poke.iterrows():
    #print(index,row)
   
#Read specifc location (r,c)
#print (poke.iloc[2,4])


#poke.loc[poke["Type 1"]=="Fire"]
#poke.describe()

#poke.sort_values(['Type 1','HP'] )

# %%
poke.head(5)

# %%
# Out:
# 143

# %%
#poke['Total']=poke['HP']+poke['Attack'] + poke['Defense']

#poke=poke.drop(columns=['Total'])
#poke['Total']=poke.iloc[:,4:10].sum(axis=1)
#poke.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
poke['Total']=poke.iloc[:,4:10].sum(axis=1)
poke.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
#poke.to_csv("modi fied.csv")
#poke.to_excel("modi fied.xlsx")
#poke.to_csv("modi fied.txt , index=False sp=\t")

# %%
#poke.loc[(poke["Type 1"]=="Grass") &(poke["Type 2"]=="Poison")]
#poke.loc[(poke["Type 1"]=="Grass") |(poke["Type 2"]=="Poison")] ## in pandas and = &   and or = |
#poke.loc[(poke["Type 1"]=="Grass") &(poke["Type 2"]=="Poison")& (poke["HP"]>70)] شرط اخر 
#new_poke=poke.loc[(poke["Type 1"]=="Grass") &(poke["Type 2"]=="Poison")& (poke["HP"]>70)]
#new_poke
#new_poke=poke.to_csv("modi fied1.csv")

#new_poke=new_poke.reset_index()
#new_poke

#new_poke=new_poke.reset_index(drop=True) ##لمسح القيم القديمة 
#new_poke
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c8d3e66d5ce5> in <module>
# ----> 1 poke.loc[(poke["Type 1"]=="Grass") &(poke["Type 2"]=="Poison")]
#       2 #poke.loc[(poke["Type 1"]=="Grass") |(poke["Type 2"]=="Poison")] ## in pandas and = &   and or = |
#       3 #poke.loc[(poke["Type 1"]=="Grass") &(poke["Type 2"]=="Poison")& (poke["HP"]>70)] شرط اخر
#       4 #new_poke=poke.loc[(poke["Type 1"]=="Grass") &(poke["Type 2"]=="Poison")& (poke["HP"]>70)]
#       5 #new_poke
#
# NameError: name 'poke' is not defined

# %%
#poke.loc[-poke["Name"].str.contains("Mega")] # اظهار كل القيم التي ليس فيها كلمة اوميقا  لي النفي نستخدم 
#import re
#poke.loc[poke["Type 1"].str.contains("Fire|Grass",regex=True)]
#poke.loc[poke["Name"].str.contains("pi[a-z]",regex=True)]# احضار كل البوكيمونات في اسمها pi 
#poke.loc[poke["Name"].str.contains("^pi[a-z]*",regex=True)]# احضار كل البوكيمونات في بداية اسمها  pi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-addcf999a081> in <module>
# ----> 1 poke.loc[-poke["Name"].str.contains("Mega")] # اظهار كل القيم التي ليس فيها كلمة اوميقا  لي النفي نستخدم
#       2 #import re
#       3 #poke.loc[poke["Type 1"].str.contains("Fire|Grass",regex=True)]
#       4 #poke.loc[poke["Name"].str.contains("pi[a-z]",regex=True)]# احضار كل البوكيمونات في اسمها pi
#       5 #poke.loc[poke["Name"].str.contains("^pi[a-z]*",regex=True)]# احضار كل البوكيمونات في بداية اسمها  pi
#
# NameError: name 'poke' is not defined

# %%
poke
# Out:
#         #                 Name   Type 1 Type 2    HP Attack Defense Sp. Atk  \
# 0    True                 True     True   True  True   True    True    True
# 1    True                 True     True   True  True   True    True    True
# 2    True                 True     True   True  True   True    True    True
# 3    True                 True     True   True  True   True    True    True
# 4       4           Charmander     Fire    NaN    39     52      43      60
# ..    ...                  ...      ...    ...   ...    ...     ...     ...
# 795   719              Diancie     Rock  Fairy    50    100     150     100
# 796   719  DiancieMega Diancie     Rock  Fairy    50    160     110     160
# 797   720  HoopaHoopa Confined  Psychic  Ghost    80    110      60     150
# 798   720   HoopaHoopa Unbound  Psychic   Dark    80    160      60     170
# 799   721            Volcanion     Fire  Water    80    110     120     130
#
#     Sp. Def Speed Generation Legendary Total
# ...

# %%
pok
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
#pok['Total']=pok.iloc[:,4:10].sum(axis=1)
#pok.to_csv("modi fied1.csv")

#pok.loc[pok['Total'] >500, ['Generation','Legendary']]=['Test1','test2'] # شروط متعددة 
#pok
pok=pd.read_csv("modi fied1.csv")
pok#
# Out:
#      Unnamed: 0    #                   Name   Type 1  Type 2  HP  Attack  \
# 0             0    1              Bulbasaur    Grass  Poison  45      49
# 1             1    2                Ivysaur    Grass  Poison  60      62
# 2             2    3               Venusaur    Grass  Poison  80      82
# 3             3    3  VenusaurMega Venusaur    Grass  Poison  80     100
# 4             4    4             Charmander     Fire     NaN  39      52
# ..          ...  ...                    ...      ...     ...  ..     ...
# 795         795  719                Diancie     Rock   Fairy  50     100
# 796         796  719    DiancieMega Diancie     Rock   Fairy  50     160
# 797         797  720    HoopaHoopa Confined  Psychic   Ghost  80     110
# 798         798  720     HoopaHoopa Unbound  Psychic    Dark  80     160
# 799         799  721              Volcanion     Fire   Water  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# ...

# %%
#pok.columns(["Type 1"]).mean().sort_values('Attack', ascending = False) # استختدام المتوسط بشكل مجموعات وترتيبهم 
#pok.groupby(["Type 1"]).sum() #مجموع القيم على حسب type1
#pok.groupby(["Type 1"]).count()#عدد القيم على حسب type1
#pok['count']=1
#pok.groupby(["Type 1"]).count() ['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
#new_pok=pd.Dataframe(columns=pok.columns)
##for pok in pd.read_csv("modi fied.csv",chunksize=5):
   # result=pok.groupby(["Type 1"]).count
   # new_pok=pd.concat(([new_pok,results]))
# Out:
#   File "<ipython-input-64-658c7f933b94>", line 6
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
import numpy as np
for a in np.arange(0.5,10):
    print(a)
# Out:
# 0.5
# 1.5
# 2.5
# 3.5
# 4.5
# 5.5
# 6.5
# 7.5
# 8.5
# 9.5
