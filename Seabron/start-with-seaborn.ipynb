# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/kaggle/input/pokemon/pokemon_data.csv")
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
#sns.namefun(x=value,y=value, hue='NAME VAR ,data= name data)
sns.scatterplot(x="Attack",y="Defense" , hue="Type 1" , data=df)
sns.set_context("paper")

# %%
sns.boxplot(x="Attack",data=df,hue="Type 1")
# Out:
# <AxesSubplot:xlabel='Attack'>

# %%
top=df.sample(5)
top
# Out:
#        #        Name  Type 1    Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 43    38   Ninetales    Fire       NaN  73      76       75       81      100
# 499  449  Hippopotas  Ground       NaN  68      72       78       38       42
# 608  548     Petilil   Grass       NaN  45      35       50       70       50
# 620  559     Scraggy    Dark  Fighting  50      75       70       35       70
# 758  688     Binacle    Rock     Water  42      52       67       39       56
#
#      Speed  Generation  Legendary
# 43     100           1      False
# 499     32           4      False
# 608     30           5      False
# 620     48           5      False
# 758     50           6      False

# %%
fig, ax=plt.subplots(figsize=(8,8))
sns.lineplot(x="Attack",y="Defense" , hue="Type 1",data=df)
# Out:
# <AxesSubplot:xlabel='Attack', ylabel='Defense'>

# %%
sns.swarmplot(x="Attack",y="Speed",hue="Type 1",data=top)
# Out:
# <AxesSubplot:xlabel='Attack', ylabel='Speed'>

# %%
sns.barplot(x="Name",y="Speed",hue="Name",data=top)
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Speed'>

# %%
sns.boxenplot(df.describe())
# Out:
# <AxesSubplot:>

# %%
#sns.pairplot(data=name_of_data, hue=label)
sns.pairplot(data=df, hue="Legendary")

# %%
#pie chat
#sns.# Create a data frame of adjudicated_gradable counts 
gradable_counts = df['Type 1'].value_counts()

# Plot a pie chart

gradable_counts.plot(kind='pie', title='Type 1 Counts', figsize=(8,6)) 

plt.legend()
plt.show()

# %%
#bar chart
#For jupyter to visualize data %matplotlib inline
# %matplotlib inline 
# Recall seaborn library
#import seabor as sns
fig, ax=plt.subplots(figsize=(8,6)) # size figure
sns.lineplot(x='Attack',y='Defense', data=df, hue="Legendary") 
plt.title(" Contract by Legendary")
# Out:
# Text(0.5, 1.0, ' Contract by Legendary')
